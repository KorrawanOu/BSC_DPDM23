# %% [markdown]
# <a href="https://colab.research.google.com/github/KorrawanOu/BSC_DPDM23/blob/main/ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import os
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df = pd.read_excel('/content/drive/MyDrive/BSCproject/psdexercise.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          ปี      ภาค      จังหวัด             อำเภอ        ตำบล   เพศ อายุ  \
# 0      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง   55
# 1      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง   47
# 2      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   45
# 3      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   53
# 4      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   57
# ...     ...      ...          ...               ...         ...   ...  ...
# 20093  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง   48
# ...

# %% [markdown]
# #Prepare and Clean data

# %% [markdown]
# ## เปลี่ยนชื่อ column กิจกรรม_2564 เป็น กิจกรรม

# %%
df = df.rename(columns={'กิจกรรม_2564': 'กิจกรรม'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
region_counts = df['ภาค'].value_counts()
region_counts
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ภาคตะวันออกเฉียงเหนือ    5555
# ภาคกลาง                  5012
# ภาคเหนือ                 4644
# ภาคใต้                   4286
# กรุงเทพมหานคร             601
# Name: ภาค, dtype: int64

# %% [markdown]
# เนื่องจากมีภาคกรุงเทพมหานคร ซึ่งไม่ใช่ และต้องเปลี่ยนเป็นภาคกลาง

# %%
df.loc[df['ภาค'] == 'กรุงเทพมหานคร', 'ภาค'] = 'ภาคกลาง'
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
region_counts = df['ภาค'].value_counts()
region_counts
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ภาคกลาง                  5613
# ภาคตะวันออกเฉียงเหนือ    5555
# ภาคเหนือ                 4644
# ภาคใต้                   4286
# Name: ภาค, dtype: int64

# %% [markdown]
# ##แก้ภาคกรุงเทพมหานครเป็นภาคกลาง
# - แก้ภาคต่างๆเป็น 1 = ภาคเหนือ,
# 2 = ภาคกลาง,
# 3 = ภาคตะวันออกเฉียงเหนือ,
# 4 = ภาคใต้

# %%
df.loc[df['ภาค'] == 'ภาคเหนือ', 'ภาค'] = 1
df.loc[df['ภาค'] == 'ภาคกลาง', 'ภาค'] = 2
df.loc[df['ภาค'] == 'ภาคตะวันออกเฉียงเหนือ', 'ภาค'] = 3
df.loc[df['ภาค'] == 'ภาคใต้', 'ภาค'] = 4
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          ปี ภาค      จังหวัด             อำเภอ        ตำบล   เพศ อายุ  \
# 0      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง   55
# 1      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง   47
# 2      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   45
# 3      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   53
# 4      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   57
# ...     ...  ..          ...               ...         ...   ...  ...
# 20093  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง   48
# ...

# %%
df[['กิจกรรม_2564']]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                     กิจกรรม_2564
# 0                 (1)ปั่นจักรยาน
# 1                              -
# 2                              -
# 3                        (1)วิ่ง
# 4                 (1)ปั่นจักรยาน
# ...                          ...
# 20093            (1)เดิน,(2)วิ่ง
# 20094          (1)เดิน,(2)ฟุตบอล
# 20095  (1)เดิน,(2)วิ่ง,(3)ฟุตบอล
# 20096                    (1)เดิน
# 20097              (1)วอลเลย์บอล
#
# [20098 rows x 1 columns]

# %% [markdown]
# ## จัดกลุ่มอายุ

# %%
df['อายุ']
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0        55
# 1        47
# 2        45
# 3        53
# 4        57
#          ..
# 20093    48
# 20094    29
# 20095    40
# 20096    35
# 20097    35
# Name: อายุ, Length: 20098, dtype: object

# %%
df['อายุ'] = pd.to_numeric(df['อายุ'], errors='coerce').astype('Int64')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-376-da0e4a18e869>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['อายุ'] = pd.to_numeric(df['อายุ'], errors='coerce').astype('Int64')

# %%
df = df.dropna()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.isnull().any()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ปี                   False
# ภาค                  False
# จังหวัด              False
# อำเภอ                False
# ตำบล                 False
# เพศ                  False
# อายุ                 False
# การศึกษา             False
# สถานภาพ              False
# การมีโรคประจำตัว     False
# ประเภทของโรค         False
# อาชีพ                False
# น้ำหนัก              False
# ส่วนสูง              False
# กิจกรรม              False
# ระดับ                False
# นาที/วัน             False
# วัน/สัปดาห์          False
# รวมสรุปกิจกรรม       False
# สถานที่              False
# เวลา                 False
# เวลารวม (ชั่วโมง)    False
# ...

# %%
from matplotlib import pyplot as plt
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
bp_age = plt.boxplot([df['อายุ']],
             labels=['Age'])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### สร้างฟังก์ชันลบค่า outliers และหาค่า min max q1 q2 q3

# %%
def detail_boxreturn(boxreturn):
    q1 = boxreturn['boxes'][0].get_ydata()[0]
    q2 = boxreturn['medians'][0].get_ydata()[0]
    q3 = boxreturn['boxes'][0].get_ydata()[2]
    minv = min(boxreturn['whiskers'][0].get_ydata())
    maxv = max(boxreturn['whiskers'][1].get_ydata())
    print(f'min = {minv}, max = {maxv}, q1 = {q1}, q2 = {q2}, q3 = {q3}')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
detail_boxreturn(bp_age)
# Out:
# min = 15.0, max = 95.0, q1 = 35.0, q2 = 49.0, q3 = 59.0
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### แบ่งตาม min max q1 q2 q3 และลบค่าที่มากกว่า 95 ออก
# - กลุ่มที่ 1 = อายุ 15-35 ปี
# - กลุ่มที่ 2 = อายุ 36-49 ปี
# - กลุ่มที่ 3 = อายุ 50-59 ปี
# - กลุ่มที่ 4 = อายุ 60-95 ปี

# %%
df = df.loc[df['อายุ'] <= 95]
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          ปี ภาค      จังหวัด             อำเภอ        ตำบล   เพศ  อายุ  \
# 0      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง    55
# 1      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง    47
# 2      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย    45
# 3      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย    53
# 4      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย    57
# ...     ...  ..          ...               ...         ...   ...   ...
# 20093  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง    48
# ...

# %%
bp_age = plt.boxplot([df['อายุ']],
             labels=['Age']) # จะเห็นได้ว่าไม่มีค่า outliers แล้ว
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ###กำหนดช่วงอายุ

# %%
age_1 =df[(df['อายุ']>15) & (df['อายุ']<=35)].count().sum()
age_1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 134264

# %%
df.loc[(df['อายุ'] >= 15) & (df['อายุ'] <= 35), 'อายุ'] = 1
df.loc[(df['อายุ'] >= 36) & (df['อายุ'] <= 49), 'อายุ'] = 2
df.loc[(df['อายุ'] >= 50) & (df['อายุ'] <= 59), 'อายุ'] = 3
df.loc[(df['อายุ'] >= 60) & (df['อายุ'] <= 95), 'อายุ'] = 4
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          ปี ภาค      จังหวัด             อำเภอ        ตำบล   เพศ  อายุ  \
# 0      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง     3
# 1      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง     2
# 2      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     2
# 3      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# 4      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# ...     ...  ..          ...               ...         ...   ...   ...
# 20093  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง     2
# ...

# %% [markdown]
# ## จัดกลุ่มสถานภาพ

# %%
status_counts = df['สถานภาพ'].value_counts()
status_counts
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# สมรส                            11945
# โสด                              6078
# หม้าย                            1469
# หย่า                              339
# แยกกันอยู่                        205
# อื่น ๆ                              4
# อยู่ร่วมกัน                         3
# ไม่ได้จดทะเบียนสมรส                 2
# ไม่จดทะเบียนสมรส                    2
# สมรสไม่จดทะเบียน                    2
# มีแฟน                               1
# ไม่ได้แต่งงานแต่มีลูกด้วยกัน        1
# สมรสไม่ได้จดทะเบียน                 1
# ไม่ได้จดทะเบียน                     1
# Name: สถานภาพ, dtype: int64

# %%
df['สถานภาพ'] = df['สถานภาพ'].replace({'หม้าย': 3,'หย่า': 3,'แยกกันอยู่': 3,'สมรส': 2, 'โสด': 1,'อื่น ๆ': 1,'อยู่ร่วมกัน': 1,'ไม่ได้จดทะเบียนสมรส': 1,'ไม่จดทะเบียนสมรส': 1,'สมรสไม่จดทะเบียน': 1,'ไม่ได้แต่งงานแต่มีลูกด้วยกัน': 1,'สมรสไม่ได้จดทะเบียน': 1,'ไม่ได้จดทะเบียน': 1,'มีแฟน': 1})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
status_counts = df['สถานภาพ'].value_counts()
status_counts
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2    11945
# 1     6095
# 3     2013
# Name: สถานภาพ, dtype: int64

# %% [markdown]
# ##จัดกลุ่มการมีโรคประจำตัว

# %% [markdown]
# แก้ "-" ใน column การมีโรคประจำตัว	เป็นคำว่า "ไม่มี"

# %%
no_disease = df['การมีโรคประจำตัว'].str.count('-').sum()
no_disease
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0

# %%
df.loc[df['การมีโรคประจำตัว'].str.contains('-'), 'การมีโรคประจำตัว'] = 'ไม่มี'
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
no_disease = df['การมีโรคประจำตัว'].str.count('-').sum()
no_disease
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          ปี ภาค      จังหวัด             อำเภอ        ตำบล   เพศ  อายุ  \
# 0      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง     3
# 1      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง     2
# 2      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     2
# 3      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# 4      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# ...     ...  ..          ...               ...         ...   ...   ...
# 20093  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง     2
# ...

# %%
# https://www.geeksforgeeks.org/using-apply-in-pandas-lambda-functions-with-multiple-if-statements/
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.loc[(df['อายุ'] >= 15) & (df['อายุ'] <= 35), 'อายุ'] = 1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df['การมีโรคประจำตัว'] = df['การมีโรคประจำตัว'].apply(lambda x: 0 if x == 'ไม่มี' else 1)

df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          ปี ภาค      จังหวัด             อำเภอ        ตำบล   เพศ  อายุ  \
# 0      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง     3
# 1      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง     2
# 2      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     2
# 3      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# 4      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# ...     ...  ..          ...               ...         ...   ...   ...
# 20093  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง     2
# ...

# %% [markdown]
# ##จัดกลุ่มออกกำลังกาย/ไม่ออกกำลังกาย

# %%
df['กิจกรรม'] = df['กิจกรรม'].apply(lambda x: 0 if x == '-' else 1)
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          ปี ภาค      จังหวัด             อำเภอ        ตำบล   เพศ  อายุ  \
# 0      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง     3
# 1      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง     2
# 2      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     2
# 3      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# 4      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# ...     ...  ..          ...               ...         ...   ...   ...
# 20093  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง     2
# ...

# %% [markdown]
# ##จัดกลุ่มเพศ

# %%
df['เพศ'] = df['เพศ'].replace({'ชาย': 0, 'หญิง': 1})
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          ปี ภาค      จังหวัด             อำเภอ        ตำบล  เพศ  อายุ  \
# 0      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ    1     3
# 1      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ    1     2
# 2      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ    0     2
# 3      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ    0     3
# 4      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ    0     3
# ...     ...  ..          ...               ...         ...  ...   ...
# 20093  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส    1     2
# ...

# %% [markdown]
# ##จัดกลุ่มระดับการออกกำลังกาย

# %% [markdown]
# split ระดับการออกกำหลังกาย

# %%
gf = df['รวมสรุปกิจกรรม'].str.split(',', expand = True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
gf1 = gf[0].str.split('(', expand = True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df['รวมสรุปกิจกรรม'] = gf1[[1]]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df = df.fillna('-')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df['รวมสรุปกิจกรรม'] = df['รวมสรุปกิจกรรม'].replace({'-': 0, 'ระดับปานกลาง': 1, 'ระดับหนัก': 2})
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          ปี  ภาค      จังหวัด             อำเภอ        ตำบล  เพศ  อายุ  \
# 0      2564    2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ    1     3
# 1      2564    2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ    1     2
# 2      2564    2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ    0     2
# 3      2564    2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ    0     3
# 4      2564    2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ    0     3
# ...     ...  ...          ...               ...         ...  ...   ...
# 20093  2565    4     นราธิวาส             ระแงะ   ตันหยงมัส    1     2
# ...

# %% [markdown]
# #### ทดเวลาบาดเจ็บ

# %% [markdown]
# #Clasification

# %% [markdown]
# ## Class1 => กิจกรรม

# %%
df_c_1 = df[['ปี','ภาค','เพศ','อายุ',
       'สถานภาพ', 'การมีโรคประจำตัว','กิจกรรม']]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_c_1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          ปี  ภาค  เพศ  อายุ  สถานภาพ  การมีโรคประจำตัว  กิจกรรม
# 0      2564    2    1     3        3                 0        1
# 1      2564    2    1     2        2                 0        0
# 2      2564    2    0     2        2                 0        0
# 3      2564    2    0     3        2                 0        1
# 4      2564    2    0     3        2                 1        1
# ...     ...  ...  ...   ...      ...               ...      ...
# 20093  2565    4    1     2        3                 0        1
# 20094  2565    4    0     1        2                 0        1
# ...

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Model

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV,train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report,confusion_matrix
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
X = df_c_1.drop("กิจกรรม", axis=1)#ดรอปคอลัมน์ กิจกรรม เก็บไว้ในตัวแปร X
y = df_c_1["กิจกรรม"]#เลือกคอลัมน์ กิจกรรม เก็บไว้ในตัวแปร y
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.2,shuffle = True,random_state=1) #แบ่งข้อมูลเป็น Train 80% Test 20%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#ดูจำนวนแถวและคอลัมน์
print(f'Number of X train: {X_train.shape}')
print(f'Number of X test: {X_test.shape}')
print(f'Number of y train: {y_train.shape}')
print(f'Number of y test: {y_test.shape}')
# Out:
# Number of X train: (16042, 6)
# Number of X test: (4011, 6)
# Number of y train: (16042,)
# Number of y test: (4011,)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Define the parameter grid to search over
parameters_knn = {'n_neighbors': [3, 5, 7, 9, 11],
              'weights': ['uniform', 'distance'],
              'algorithm': ['ball_tree', 'kd_tree', 'brute']}

# Create the KNN classifier
knn1 = KNeighborsClassifier()

# Create a GridSearchCV object with 10-fold cross-validation
grid_knn1 = GridSearchCV(estimator=knn1, param_grid=parameters_knn, cv=10, n_jobs=-1, verbose=3,scoring = "accuracy")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# %%time
# Fit the GridSearchCV object to the training data
grid_knn1.fit(X_train, y_train)
# Print the best hyperparameters
print("Best hyperparameters: ", grid_knn1.best_params_)
# Out:
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Best hyperparameters:  {'algorithm': 'brute', 'n_neighbors': 11, 'weights': 'uniform'}
# CPU times: user 755 ms, sys: 185 ms, total: 940 ms
# Wall time: 26.7 s

# %% [markdown]
# ## Train KNN model (acc)

# %%
from sklearn.neighbors import KNeighborsClassifier
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Instantiate KNN model
knn1 = KNeighborsClassifier(n_neighbors=11, weights='uniform', algorithm='ball_tree')

# Fit the model to the training data
knn1.fit(X_train, y_train)

# Predict the test data
y_pred = knn1.predict(X_test)

#Evaluation
from sklearn.metrics import accuracy_score, classification_report
print(f'accuracy = {accuracy_score(y_test, y_pred)}')
print(classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# accuracy = 0.7541760159561207
#               precision    recall  f1-score   support
#
#            0       0.33      0.05      0.09       938
#            1       0.77      0.97      0.86      3073
#
#     accuracy                           0.75      4011
#    macro avg       0.55      0.51      0.47      4011
# weighted avg       0.67      0.75      0.68      4011

# %% [markdown]
# # Association rules

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          ปี ภาค      จังหวัด             อำเภอ        ตำบล   เพศ อายุ  \
# 0      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง   55
# 1      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง   47
# 2      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   45
# 3      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   53
# 4      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   57
# ...     ...  ..          ...               ...         ...   ...  ...
# 20093  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง   48
# ...

# %%
import pandas as pd
import os
# !pip install apyori
from apyori import apriori
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...

# %%
associate = df[['ปี','ภาค','เพศ','อายุ','กิจกรรม_2564','เหตุผล (ออก)','เวลา']]
associate
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          ปี ภาค   เพศ อายุ               กิจกรรม_2564  \
# 0      2564   2  หญิง   55             (1)ปั่นจักรยาน
# 1      2564   2  หญิง   47                          -
# 2      2564   2   ชาย   45                          -
# 3      2564   2   ชาย   53                    (1)วิ่ง
# 4      2564   2   ชาย   57             (1)ปั่นจักรยาน
# ...     ...  ..   ...  ...                        ...
# 20093  2565   4  หญิง   48            (1)เดิน,(2)วิ่ง
# 20094  2565   4   ชาย   29          (1)เดิน,(2)ฟุตบอล
# 20095  2565   4   ชาย   40  (1)เดิน,(2)วิ่ง,(3)ฟุตบอล
# 20096  2565   4   ชาย   35                    (1)เดิน
# ...

# %%
df.columns
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Index(['ปี', 'ภาค', 'จังหวัด', 'อำเภอ', 'ตำบล', 'เพศ', 'อายุ', 'การศึกษา',
#        'สถานภาพ', 'การมีโรคประจำตัว', 'ประเภทของโรค', 'อาชีพ', 'น้ำหนัก',
#        'ส่วนสูง', 'กิจกรรม', 'ระดับ', 'นาที/วัน', 'วัน/สัปดาห์',
#        'รวมสรุปกิจกรรม', 'สถานที่', 'เวลา', 'เวลารวม (ชั่วโมง)',
#        'เหตุผล (ออก)', 'เหตุผล (ไม่ออก)', 'แรงจูงใจ', 'ข้อเสนอแนะ'],
#       dtype='object')

# %%
association = associate[associate['เหตุผล (ออก)'] !='-']
association
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          ปี ภาค   เพศ อายุ                       กิจกรรม_2564  \
# 0      2564   2  หญิง   55                     (1)ปั่นจักรยาน
# 3      2564   2   ชาย   53                            (1)วิ่ง
# 4      2564   2   ชาย   57                     (1)ปั่นจักรยาน
# 5      2564   2  หญิง   55                            (1)โยคะ
# 7      2564   2   ชาย   49  (1)การออกกำลังกายในการประกอบอาชีพ
# ...     ...  ..   ...  ...                                ...
# 20093  2565   4  หญิง   48                    (1)เดิน,(2)วิ่ง
# 20094  2565   4   ชาย   29                  (1)เดิน,(2)ฟุตบอล
# ...

# %%
ass_s1 = association['กิจกรรม_2564'].str.split(',', expand=False)
ass_s1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0                           [(1)ปั่นจักรยาน]
# 3                                  [(1)วิ่ง]
# 4                           [(1)ปั่นจักรยาน]
# 5                                  [(1)โยคะ]
# 7        [(1)การออกกำลังกายในการประกอบอาชีพ]
#                         ...
# 20093                     [(1)เดิน, (2)วิ่ง]
# 20094                   [(1)เดิน, (2)ฟุตบอล]
# 20095          [(1)เดิน, (2)วิ่ง, (3)ฟุตบอล]
# 20096                              [(1)เดิน]
# 20097                        [(1)วอลเลย์บอล]
# Name: กิจกรรม_2564, Length: 15501, dtype: object

# %%
ass_s1 = associate['กิจกรรม_2564']
ass_s1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0                   (1)ปั่นจักรยาน
# 1                                -
# 2                                -
# 3                          (1)วิ่ง
# 4                   (1)ปั่นจักรยาน
#                    ...
# 20093              (1)เดิน,(2)วิ่ง
# 20094            (1)เดิน,(2)ฟุตบอล
# 20095    (1)เดิน,(2)วิ่ง,(3)ฟุตบอล
# 20096                      (1)เดิน
# 20097                (1)วอลเลย์บอล
# Name: กิจกรรม_2564, Length: 20098, dtype: object

# %%
import re
def clean_row(row):
    # Remove parentheses and their contents
    row = re.sub(r'\([^)]*\)', '', row)
    # Remove numbers
    row = re.sub(r'[0-9]', '', row)
    return row.strip()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Apply the clean_row function to each row in the list
cleaned_rows = [clean_row(row) for row in ass_s1]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
cleaned_rows_1 = pd.DataFrame({'กิจกรรม': cleaned_rows})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
cleaned_rows_2 = cleaned_rows_1['กิจกรรม'].str.split(',', expand=True)

# %%
associate['กิจกรรม_2564'] = cleaned_rows_2[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-419-343ea81660d6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   associate['กิจกรรม_2564'] = cleaned_rows_2[0]

# %%
ssd = associate['กิจกรรม_2564'].value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ssd
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# เดิน                              7571
# -                                 4598
# วิ่ง                              2716
# ฟุตบอล                            1300
# ปั่นจักรยาน                       1004
# เต้นแอโรบิค                        818
# การออกกำลังกายในการประกอบอาชีพ     568
# ฟุตซอล                             301
# แบดมินตัน                          193
# โยคะ                               146
# อื่นๆ                              146
# วอลเลย์บอล                         143
# เซปักตะกร้อ                        141
# เปตอง                               90
# เต้นบัสโลบ                          77
# ...

# %%
associate1 = associate.dropna()
associate1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          ปี ภาค   เพศ อายุ กิจกรรม_2564  \
# 0      2564   2  หญิง   55  ปั่นจักรยาน
# 1      2564   2  หญิง   47            -
# 2      2564   2   ชาย   45            -
# 3      2564   2   ชาย   53         วิ่ง
# 4      2564   2   ชาย   57  ปั่นจักรยาน
# ...     ...  ..   ...  ...          ...
# 20093  2565   4  หญิง   48         เดิน
# 20094  2565   4   ชาย   29         เดิน
# 20095  2565   4   ชาย   40         เดิน
# 20096  2565   4   ชาย   35         เดิน
# 20097  2565   4  หญิง   35   วอลเลย์บอล
#
#                                             เหตุผล (ออก)  \
# 0      ต้องการให้ร่างกายแข็งแรง,ต้องการรูปร่างที่ดี/ห...
# ...

# %%
asslist = associate1['เหตุผล (ออก)'].str.split(',', expand=True)
asslist
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                      0                                 1   \
# 0              ต้องการให้ร่างกายแข็งแรง        ต้องการรูปร่างที่ดี/หุ่นดี
# 1                                     -                              None
# 2                                     -                              None
# 3              ต้องการให้ร่างกายแข็งแรง           ควบคุมน้ำหนัก/ลดน้ำหนัก
# 4              ต้องการให้ร่างกายแข็งแรง         รักษา/บรรเทาอาการเจ็บป่วย
# ...                                 ...                               ...
# 20093  ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน                              None
# ...

# %%
h = asslist[0].str.split(',', expand=False)
h1 = h.dropna()
h2 = h1.apply(list)
h3 = list(filter(lambda x: x is not None, h2))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df = pd.DataFrame(h3)
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                       0
# 0              ต้องการให้ร่างกายแข็งแรง
# 1                                     -
# 2                                     -
# 3              ต้องการให้ร่างกายแข็งแรง
# 4              ต้องการให้ร่างกายแข็งแรง
# ...                                 ...
# 20093  ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน
# 20094          ต้องการให้ร่างกายแข็งแรง
# 20095  ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน
# 20096          ต้องการให้ร่างกายแข็งแรง
# 20097  ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน
#
# [20098 rows x 1 columns]

# %%
ass_s2 = associate1['เวลา'].str.split(',', expand=True)
ass_s2
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                        0                   1                   2     3     4   \
# 0      (06.00 - 07.00 น.)  (18.00 - 19.00 น.)                None  None  None
# 1                       -                None                None  None  None
# 2                       -                None                None  None  None
# 3      (06.00 - 07.00 น.)  (18.00 - 19.00 น.)                None  None  None
# 4      (07.00 - 08.00 น.)  (18.00 - 19.00 น.)                None  None  None
# ...                   ...                 ...                 ...   ...   ...
# ...

# %%
associate1['เวลา'] = ass_s2[0]
associate1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          ปี ภาค   เพศ อายุ กิจกรรม_2564  \
# 0      2564   2  หญิง   55  ปั่นจักรยาน
# 1      2564   2  หญิง   47            -
# 2      2564   2   ชาย   45            -
# 3      2564   2   ชาย   53         วิ่ง
# 4      2564   2   ชาย   57  ปั่นจักรยาน
# ...     ...  ..   ...  ...          ...
# 20093  2565   4  หญิง   48         เดิน
# 20094  2565   4   ชาย   29         เดิน
# 20095  2565   4   ชาย   40         เดิน
# 20096  2565   4   ชาย   35         เดิน
# 20097  2565   4  หญิง   35   วอลเลย์บอล
#
#                                             เหตุผล (ออก)                เวลา
# ...

# %%
jaa = associate1.replace({'-' : np.NaN})
jaa
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          ปี  ภาค   เพศ  อายุ กิจกรรม_2564  \
# 0      2564    2  หญิง  55.0  ปั่นจักรยาน
# 1      2564    2  หญิง  47.0          NaN
# 2      2564    2   ชาย  45.0          NaN
# 3      2564    2   ชาย  53.0         วิ่ง
# 4      2564    2   ชาย  57.0  ปั่นจักรยาน
# ...     ...  ...   ...   ...          ...
# 20093  2565    4  หญิง  48.0         เดิน
# 20094  2565    4   ชาย  29.0         เดิน
# 20095  2565    4   ชาย  40.0         เดิน
# 20096  2565    4   ชาย  35.0         เดิน
# 20097  2565    4  หญิง  35.0   วอลเลย์บอล
#
#                                             เหตุผล (ออก)                เวลา
# ...

# %%
j1 = jaa.dropna()
j1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          ปี  ภาค   เพศ  อายุ                    กิจกรรม_2564  \
# 0      2564    2  หญิง  55.0                     ปั่นจักรยาน
# 3      2564    2   ชาย  53.0                            วิ่ง
# 4      2564    2   ชาย  57.0                     ปั่นจักรยาน
# 5      2564    2  หญิง  55.0                            โยคะ
# 7      2564    2   ชาย  49.0  การออกกำลังกายในการประกอบอาชีพ
# ...     ...  ...   ...   ...                             ...
# 20093  2565    4  หญิง  48.0                            เดิน
# 20094  2565    4   ชาย  29.0                            เดิน
# 20095  2565    4   ชาย  40.0                            เดิน
# ...

# %%
ka = j1[['กิจกรรม_2564','เวลา']]
ka
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                          กิจกรรม_2564                เวลา
# 0                         ปั่นจักรยาน  (06.00 - 07.00 น.)
# 3                                วิ่ง  (06.00 - 07.00 น.)
# 4                         ปั่นจักรยาน  (07.00 - 08.00 น.)
# 5                                โยคะ  (16.00 - 17.00 น.)
# 7      การออกกำลังกายในการประกอบอาชีพ  (09.00 - 10.00 น.)
# ...                               ...                 ...
# 20093                            เดิน  (05.00 - 06.00 น.)
# 20094                            เดิน  (05.00 - 06.00 น.)
# 20095                            เดิน  (05.00 - 06.00 น.)
# ...

# %%
a= ka.replace({'(05.00 - 06.00 น.)' : 'เช้า'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
b= a.replace({'(07.00 - 08.00 น.)' : 'เช้า'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
c=b.replace({'(06.00 - 07.00 น.)' : 'เช้า'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
d = c.replace({'(08.00 - 09.00 น.)' : 'เช้า'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
e  = d.replace({'(09.00 - 10.00 น.)' : 'เที่ยง'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
f=e.replace({'(10.00 - 11.00 น.)' : 'เที่ยง'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
i =f.replace({'(11.00 - 12.00 น.)' : 'เที่ยง'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
j =i.replace({'(12.00 - 13.00 น.)' : 'เที่ยง'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
k =j.replace({'(12.00 - 13.00 น.)' : 'เที่ยง'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
l =k.replace({'(13.00 - 14.00 น.)' : 'บ่าย'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
m =l.replace({'(14.00 - 15.00 น.)' : 'บ่าย'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
n =m.replace({'(15.00 - 16.00 น.)' : 'บ่าย'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
o =n.replace({'(16.00 - 17.00 น.)' : 'บ่าย'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
p =o.replace({'(17.00 - 18.00 น.)' : 'เย็น'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
q =p.replace({'(18.00 - 19.00 น.)' : 'เย็น'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
r =q.replace({'(19.00 - 20.00 น.)' : 'เย็น'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
aa = r.replace({'(20.00 - 21.00 น.)' : 'เย็น'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
bb =aa.replace({'(21.00 - 22.00 น.)' : 'ค่ำ'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
cc =bb.replace({'(22.00 - 23.00 น.)' : 'ค่ำ'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
dd =cc.replace({'(23.00 - 24.00 น.)' : 'ค่ำ'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ee =dd.replace({'(00.00 - 01.00 น.)' : 'ค่ำ'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ff =ee.replace({'(01.00 - 02.00 น.)' : 'ดึก'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ii =ff.replace({'(02.00 - 03.00 น.)' : 'ดึก'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
jj=ii.replace({'(03.00 - 04.00 น.)' : 'ดึก'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
kk=jj.replace({'(04.00 - 05.00 น.)' : 'ดึก'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
kk['เวลา'].value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# เย็น      6295
# เช้า      5929
# บ่าย      2669
# ดึก        318
# เที่ยง     270
# ค่ำ         18
# Name: เวลา, dtype: int64

# %%
j1['เวลา'] = kk['เวลา']
j1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-458-2097cc928e8c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   j1['เวลา'] = kk['เวลา']
#          ปี  ภาค   เพศ  อายุ                    กิจกรรม_2564  \
# 0      2564    2  หญิง  55.0                     ปั่นจักรยาน
# 3      2564    2   ชาย  53.0                            วิ่ง
# 4      2564    2   ชาย  57.0                     ปั่นจักรยาน
# ...

# %%
jaa = associate1.replace({'-' : np.NaN})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# !pip install apyori
from apyori import apriori
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...

# %% [markdown]
# ##ช่วงเช้าตรู่

# %%
mor= j2[(j2['เวลา'] == 'เช้า')]
mor
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#            ภาค   เพศ กิจกรรม_2564  \
# 0      ภาคกลาง  หญิง  ปั่นจักรยาน
# 3      ภาคกลาง   ชาย         วิ่ง
# 4      ภาคกลาง   ชาย  ปั่นจักรยาน
# 8      ภาคกลาง  หญิง         เดิน
# 12     ภาคกลาง   ชาย         เดิน
# ...        ...   ...          ...
# 20091   ภาคใต้   ชาย         เดิน
# 20093   ภาคใต้  หญิง         เดิน
# 20094   ภาคใต้   ชาย         เดิน
# 20095   ภาคใต้   ชาย         เดิน
# 20096   ภาคใต้   ชาย         เดิน
#
#                                             เหตุผล (ออก)  เวลา
# 0      ต้องการให้ร่างกายแข็งแรง,ต้องการรูปร่างที่ดี/ห...  เช้า
# 3      ต้องการให้ร่างกายแข็งแรง,ควบคุมน้ำหนัก/ลดน้ำหน...  เช้า
# ...

# %%
trans1 = exx.groupby('กิจกรรม_2564')['เวลา'].apply(list)
trans2 = trans1.values.tolist()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
trans1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# กิจกรรม_2564
# กระโดดเชือก                       [เช้า, เช้า, เช้า, เช้า, เช้า, เช้า, เช้า, เช้...
# กายบริหาร                                                        [เช้า, เช้า, เช้า]
# การออกกำลังกายในการประกอบอาชีพ    [เช้า, เช้า, เช้า, เช้า, เช้า, เช้า, เช้า, เช้...
# บาสเกตบอล                                                              [เช้า, เช้า]
# ปั่นจักรยาน                       [เช้า, เช้า, เช้า, เช้า, เช้า, เช้า, เช้า, เช้...
# ฟุตซอล                             [เช้า, เช้า, เช้า, เช้า, เช้า, เช้า, เช้า, เช้า]
# ฟุตบอล                            [เช้า, เช้า, เช้า, เช้า, เช้า, เช้า, เช้า, เช้...
# ...

# %%
min_sup = 0.25
frequentItemsets = list(apriori(trans1,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-468-36b7aa6d3630> in <cell line: 2>()
#       1 min_sup = 0.25
# ----> 2 frequentItemsets = list(apriori(trans1,min_support = min_sup))
#       3 for i in frequentItemsets:
#       4     if i[0].__len__()>1:
#       5         print('yes')
#
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/apriori.py in apriori(df, min_support, use_colnames, max_len, verbose, low_memory)
#     239         )
#     240
# --> 241     fpc.valid_input_check(df)
# ...

# %%
frequent_itemsets = list(apriori(trans1, min_support = 0.25))

results = []

for itemset in frequent_itemsets:
    if len(itemset.items) > 1:
        item_info = {
            "yes": 'yes',
            "Items": ', '.join(itemset.items),
            "Support": f"{itemset.support:.4f} ({itemset.support*100:.2f}%)"
        }

        rules_info = []
        for rule_number, ordered_stat in enumerate(itemset.ordered_statistics, start=1):
            base_items = ', '.join(ordered_stat.items_base) if ordered_stat.items_base else 'None'
            add_items = ', '.join(ordered_stat.items_add)

            rules_info.append(f"Rule {rule_number}: ({base_items} -> {add_items} : Confidence={ordered_stat.confidence:.4f}, Lift={ordered_stat.lift:.4f})")

        item_info.update({"Rules": '\n'.join(rules_info)})
        results.append(item_info)

results_df = pd.DataFrame(results)

results_df

# %%
j2 = j1[['ภาค',"เพศ",'กิจกรรม_2564','เหตุผล (ออก)','เวลา']]
j2
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        ภาค   เพศ                    กิจกรรม_2564  \
# 0        2  หญิง                     ปั่นจักรยาน
# 3        2   ชาย                            วิ่ง
# 4        2   ชาย                     ปั่นจักรยาน
# 5        2  หญิง                            โยคะ
# 7        2   ชาย  การออกกำลังกายในการประกอบอาชีพ
# ...    ...   ...                             ...
# 20093    4  หญิง                            เดิน
# 20094    4   ชาย                            เดิน
# 20095    4   ชาย                            เดิน
# 20096    4   ชาย                            เดิน
# 20097    4  หญิง                      วอลเลย์บอล
#
# ...

# %%
ex = pd.get_dummies(j2[['เพศ','กิจกรรม_2564']])

# %%
ex

# %%
# Apply Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(ex.iloc[:, 1:], min_support=0.025, use_colnames=True)

# Generate association rules
rules1 = association_rules(frequent_itemsets, metric="confidence",min_threshold=0.0002)

# Display frequent itemsets and association rules
print("Frequent Itemsets:")
print(frequent_itemsets)
print("\nAssociation Rules:")
rules1

# %%
# Apply Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(ex.iloc[:, 1:], min_support=0.9, use_colnames=True)

# Generate association rules
rules2 = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.00)

# Display frequent itemsets and association rules
print("Frequent Itemsets:")
print(frequent_itemsets)
print("\nAssociation Rules:")
rules2

# %%
trans1 = moring.groupby('กิจกรรม_2564')['เหตุผล (ออก)'].apply(list)
trans1

# %%
frequent_itemsets = list(apriori(trans1, min_support = 0.25))

results = []

for itemset in frequent_itemsets:
    if len(itemset.items) > 1:
        item_info = {
            "yes": 'yes',
            "Items": ', '.join(itemset.items),
            "Support": f"{itemset.support:.4f} ({itemset.support*100:.2f}%)"
        }

        rules_info = []
        for rule_number, ordered_stat in enumerate(itemset.ordered_statistics, start=1):
            base_items = ', '.join(ordered_stat.items_base) if ordered_stat.items_base else 'None'
            add_items = ', '.join(ordered_stat.items_add)

            rules_info.append(f"Rule {rule_number}: ({base_items} -> {add_items} : Confidence={ordered_stat.confidence:.4f}, Lift={ordered_stat.lift:.4f})")

        item_info.update({"Rules": '\n'.join(rules_info)})
        results.append(item_info)

results_df = pd.DataFrame(results)

results_df
